# %% [markdown]
# # 🚀 Huấn luyện Generative Model trên Google Colab
#
# Notebook này được cấu hình sẵn để tự động kết nối Google Drive, cài đặt môi trường và bắt đầu tiến trình huấn luyện mô hình U-Net/VAE với GPU miễn phí của Google Colab.

# %%
# 1. Kết nối với Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# 2. Di chuyển vào thư mục dự án (Thay đổi đường dẫn nếu bạn lưu ở thư mục khác)
import os
project_path = '/content/drive/MyDrive/palm'
os.chdir(project_path)
print('Thư mục hiện tại:', os.getcwd())

# %%
# 3. Cài đặt các thư viện cần thiết
# !pip install -r requirements.txt

# %% [markdown]
# ## 🏃 Bắt đầu Huấn Luyện
# Hãy lựa chọn chạy 1 trong các ô lệnh dưới đây tùy thuộc vào mô hình bạn muốn huấn luyện.

# %%
# Lựa chọn 1: Huấn luyện Probabilistic U-Net trên MNIST
# !python -m tools.train_generative_model --config config/mnist_unet.yaml

# %%
# Lựa chọn 2: Huấn luyện mạng VAE thông thường
# !python -m tools.train_generative_model --config config/default.yaml
